# %%
from pymongo import MongoClient

# %%
client = MongoClient()

# %%
db = client.test

# %%
db.inventory.find( {} )

# %%
cursor = db.products.find( {'Country':'Germany'})

# %%
type(_)
# Out:
# pymongo.cursor.Cursor

# %%
for documents in cursor:
    print (documents)
# Out:
# {'_id': ObjectId('6042173f0e62b760431d2f64'), '': 106, 'UserLanguage': 'EN', 'Dem_age': 23, 'Dem_gender': 'Female', 'Dem_edu': 'College degree, bachelor, master', 'Dem_edu_mom': 'Up to 12 years of school', 'Dem_employment': 'Full time employed', 'Country': 'Germany', 'Dem_Expat': 'yes', 'Dem_maritalstatus': 'Married/cohabiting', 'Dem_dependents': 0.0, 'Dem_riskgroup': 'No', 'Dem_isolation': 'Life carries on with minor changes', 'Dem_isolation_adults': 1.0, 'Dem_isolation_kids': 0.0, 'Scale_PSS10_UCLA_1': 2.0, 'Scale_PSS10_UCLA_2': 3.0, 'Scale_PSS10_UCLA_3': 3.0, 'Scale_PSS10_UCLA_4': 4.0, 'Scale_PSS10_UCLA_5': 4.0, 'Scale_PSS10_UCLA_6': 1.0, 'Scale_PSS10_UCLA_7': 4.0, 'Scale_PSS10_UCLA_8': 4.0, 'Scale_PSS10_UCLA_9': 2.0, 'Scale_PSS10_UCLA_10': 1.0, 'Scale_SLON_1': 2.0, 'Scale_SLON_2': 1.0, 'Scale_SLON_3': 1.0, 'OECD_people_1': 7.0, 'OECD_people_2': 8.0, 'OECD_insititutions_1': 8.0, 'OECD_insititutions_2': 6.0, 'OECD_insititutions_3': 6.0, 'OECD_insititutions_4': 9.0, 'OECD_insitituti
# ...
